# %% [markdown]
# Language translator is one of those apps that helped us a lot. Google Translator API helps us to create our translator using Python. In this file we create an interactive language translator.

# %% [markdown]
# ### Language Translator
#
# We can easily translate any language using Google translator, but creating our translator will be a satisfying experience as a programmer. The googletrans API created by Google developers was used earlier to translate any text using Python. But now the new API from the Google developers known as **google_trans_new** is used for the same task.
#
# We can use this API for every task that we can do with the google translator. we can easily install this library in our systems by using the **pip command**; `pip install google_trans_new`. To make a translator more interactive we will also create an interactive user interface by using the **streamlit library** in Python. Now let’s see how to create an interactive language translator:

# %%
# !pip install torch==1.9.0 --user

# %%
# !pip install Pillow==8.2.0 --user

# %%
# !pip install google_trans_new
# !pip install streamlit --user

# %%
from google_trans_new import google_translator
import streamlit as st

# %%
translator = google_translator()
translator.translate("awesome", lang_tgt='fr') # translate to french language
# Out:
# ['impressionnant', 'impressionnante']

# %%
st.title("Language Translator")
text = st.text_input("Enter a text")
translate = translator.translate(text, lang_tgt='fr')
st.write(translate)
# Out:
# 2021-09-30 15:36:43.339
# ...
#   command:
#
#     streamlit run C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %% [markdown]
# **run on terminal**
#
# `streamlit run app.py`

# %% [markdown]
# Since we are using the streamlit library here, we need to run this code using the `streamlit run file_name.py` command in our terminal. After running the file a link will open in our default browser with an interactive user interface. In the text field, we can enter any text in any language, once we hit enter it will translate it to **French** as we have mentioned **fr** as our target language in the above code.
#
# Below is how the final output will appear:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Summary
#
# This is how we can create a language translator using Google translation API developed by Google developers. We can try this app with more languages and a more interactive user interface.
